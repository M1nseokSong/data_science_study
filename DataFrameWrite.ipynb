# %% [markdown]
# <a href="https://colab.research.google.com/github/M1nseokSong/data_science_study/blob/main/DataFrameWrite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
iphone_df = pd.read_csv('iphone.csv', index_col = 0)
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_df['Face ID'] = 'Yes'
iphone_df.loc['iPhone 8'] = ['2016-09-22', '4.9', '2GB', 'ios 11.0', 'No']
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16   4.7  2GB  iOS 10.0     Yes
# iPhone 7 Plus  2016-09-16   5.5  3GB  iOS 10.0     Yes
# iPhone 8       2016-09-22   4.9  2GB  ios 11.0      No
# iPhone 8 Plus  2017-09-22   5.5  3GB  iOS 11.0     Yes
# iPhone X       2017-11-03   5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21   5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21   6.5  4GB  iOS 12.0     Yes

# %%
iphone_df[['디스플레이', 'Face Id']] = 'x'
iphone_df.loc[['iPhone 7', 'iPhone X']] = 'o'
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID Face Id
# iPhone 7                o     o    o         o       o       o
# iPhone 7 Plus  2016-09-16     x  3GB  iOS 10.0     Yes       x
# iPhone 8       2016-09-22     x  2GB  ios 11.0      No       x
# iPhone 8 Plus  2017-09-22     x  3GB  iOS 11.0     Yes       x
# iPhone X                o     o    o         o       o       o
# iPhone XS      2018-09-21     x  4GB  iOS 12.0     Yes       x
# iPhone XS Max  2018-09-21     x  4GB  iOS 12.0     Yes       x

# %% [markdown]
# 삭제 하는 방법

# %%
iphone_df.drop(['iPhone X', 'iPhone XS Max'], axis='index', inplace=True)
iphone_df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID Face Id
# iPhone 7                o     o    o         o       o       o
# iPhone 7 Plus  2016-09-16     x  3GB  iOS 10.0     Yes       x
# iPhone 8       2016-09-22     x  2GB  ios 11.0      No       x
# iPhone 8 Plus  2017-09-22     x  3GB  iOS 11.0     Yes       x
# iPhone XS      2018-09-21     x  4GB  iOS 12.0     Yes       x
