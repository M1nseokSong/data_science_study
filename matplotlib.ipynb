# %% [markdown]
# <a href="https://colab.research.google.com/github/M1nseokSong/data_science_study/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import pandas as pd

df = pd.read_csv('broadcast.csv', index_col=0)
df.plot()

# %%
df.plot(y=['KBS', 'JTBC'])

# %%
df[['KBS', 'JTBC']].plot()

# %%
df1 = pd.read_csv('sports.csv', index_col = 0)
df1
# Out:
#             Male  Female
# Swimming     103     178
# Baseball     363     289
# Basketball   151      97
# Golf         154     232
# Soccer       413     109
# Bowling       88     129

# %%
df1.plot(kind='bar')

# %%
df1.plot(kind='barh')

# %%
df1.plot(kind='bar', stacked=True)

# %%
df1['Female'].plot(kind='bar')
