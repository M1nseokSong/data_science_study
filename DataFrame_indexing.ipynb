# %% [markdown]
# <a href="https://colab.research.google.com/github/M1nseokSong/data_science_study/blob/main/DataFrame_indexing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

iphone_df = pd.read_csv('iphone.csv', index_col=0)
iphone_df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_df.loc['iPhone 8', '메모리']
# Out:
# '2GB'

# %%
iphone_df.loc['iPhone X', :]
# Out:
# 출시일        2017-11-03
# 디스플레이             5.8
# 메모리               3GB
# 출시 버전        iOS 11.1
# Face ID           Yes
# Name: iPhone X, dtype: object

# %%
iphone_df.loc['iPhone X']
# Out:
# 출시일        2017-11-03
# 디스플레이             5.8
# 메모리               3GB
# 출시 버전        iOS 11.1
# Face ID           Yes
# Name: iPhone X, dtype: object

# %%
iphone_df.loc[:, '출시일']
# Out:
# iPhone 7         2016-09-16
# iPhone 7 Plus    2016-09-16
# iPhone 8         2017-09-22
# iPhone 8 Plus    2017-09-22
# iPhone X         2017-11-03
# iPhone XS        2018-09-21
# iPhone XS Max    2018-09-21
# Name: 출시일, dtype: object

# %%
iphone_df['출시일']
# Out:
# iPhone 7         2016-09-16
# iPhone 7 Plus    2016-09-16
# iPhone 8         2017-09-22
# iPhone 8 Plus    2017-09-22
# iPhone X         2017-11-03
# iPhone XS        2018-09-21
# iPhone XS Max    2018-09-21
# Name: 출시일, dtype: object

# %%
combined_df = pd.DataFrame({
    'display': iphone_df['디스플레이'],
    'memory': iphone_df['메모리']
    })
combined_df
# Out:
#                display memory
# iPhone 7           4.7    2GB
# iPhone 7 Plus      5.5    3GB
# iPhone 8           4.7    2GB
# iPhone 8 Plus      5.5    3GB
# iPhone X           5.8    3GB
# iPhone XS          5.8    4GB
# iPhone XS Max      6.5    4GB

# %%
iphone_df.loc[['iPhone 8','iPhone X'], '메모리':'Face ID']
# Out:
#           메모리     출시 버전 Face ID
# iPhone 8  2GB  iOS 11.0      No
# iPhone X  3GB  iOS 11.1     Yes

# %%
condition = (iphone_df['디스플레이'] > 5) & (iphone_df['Face ID']=='Yes')
iphone_df.loc[condition]
iphone_df[condition]
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
iphone_df["iPhone 7":"iPhone X"]
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes

# %%
iphone_df.loc[:,[True, False, False, True, True]]
# Out:
#                       출시일     출시 버전 Face ID
# iPhone 7       2016-09-16  iOS 10.0      No
# iPhone 7 Plus  2016-09-16  iOS 10.0      No
# iPhone 8       2017-09-22  iOS 11.0      No
# iPhone 8 Plus  2017-09-22  iOS 11.0      No
# iPhone X       2017-11-03  iOS 11.1     Yes
# iPhone XS      2018-09-21  iOS 12.0     Yes
# iPhone XS Max  2018-09-21  iOS 12.0     Yes

# %% [markdown]
# ![image.png](data:image/png;base64,...)![image.png]
