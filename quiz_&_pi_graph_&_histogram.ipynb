# %% [markdown]
# <a href="https://colab.research.google.com/github/M1nseokSong/data_science_study/blob/main/quiz_%26_pi_graph_%26_histogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import pandas as pd

df = pd.read_csv('silicon_valley_summary.csv')
boolean_male = df['gender']=='Male'
boolean_manager = df['job_category'] == 'Managers'
boolean_not_all = df['race_ethnicity'] != 'All'

df[boolean_male & boolean_manager & boolean_not_all].plot(kind='bar', x='race_ethnicity',  y='count')

# %%
# %matplotlib inline
import pandas as pd

df = pd.read_csv('broadcast.csv', index_col=0)
df.loc[2017].plot(kind='pie')

# %%
df = pd.read_csv('body.csv', index_col=0)
df.plot(kind='hist', y='Height')
